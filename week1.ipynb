# %% [markdown]
# <a href="https://colab.research.google.com/github/Samudrala-Hasini/NASSCOM/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import random
import os

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.
import random
from datetime import datetime, timedelta

print("\n--- Task 1: Data Generation and Basic Structures ---")

# Generate 100 simulated sensor readings
raw_sensor_data = []

# Start timestamp
start_time = datetime.now()

for i in range(100):
    timestamp = (start_time + timedelta(seconds=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"  # DEV001, DEV002, ..., DEV100

    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    # Get the reading range for the selected device type
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    # Create the reading tuple
    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

# Display the first 5 readings
for reading in raw_sensor_data[:5]:
    print(reading)

    # 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
print("\n")
print("task-2")
temperature_readings = []

for reading in raw_sensor_data:
    # Unpack the tuple
    timestamp, device_id, device_type, location, value = reading

    # Check if it is a Temperature Sensor
    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)
# Display the first 5 temperature readings
for reading in temperature_readings[:5]:
    print(reading)
print("Total Temperature Readings:", len(temperature_readings))

# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
print("\n")
print("task-3")
# Your code for Task 1.3 here:
unique_locations = set()

for reading in raw_sensor_data:
    location = reading[3]    # Location is the 4th element in the tuple
    unique_locations.add(location)

print(unique_locations)
print("Number of unique locations:", len(unique_locations))



# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
print("\n")
print("task-4")
device_stats = {}

# Initialize dictionary with large/small values
for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf'))

# Update min and max values
for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

# Display the results
for device_type, stats in device_stats.items():
    print(f"{device_type}: Min = {stats[0]}, Max = {stats[1]}")

 # 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
# Extract elements from the 10th to the 20th (inclusive)
print("\n")
print("task-1.5.1")
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Display the results
print("Readings from 10th to 20th:")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)

# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:

# Extract "Programming"
print("\n")
print("task-1.5.2")
substring_1 = sample_string[6:17]

# Extract "nohtyP" (reverse of "Python")
substring_2 = sample_string[5::-1]

# Display the results
print("Substring 1:", substring_1)
print("Substring 2:", substring_2)

# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
# Access the device_type of the 5th reading
print("\n")
print("task-1.5.3")
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Display the results
print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)

# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
print("\n")
print("task-2.1")
def get_readings_by_location(readings_list, target_location):
    location_readings = []

    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings


# Example usage
lab1_readings = get_readings_by_location(raw_sensor_data, "Lab1")

print("Readings from Lab1:")
for reading in lab1_readings[:5]:   # Display first 5 readings
    print(reading)

print("Total Lab1 readings:", len(lab1_readings))

# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
print("\n")
print("task-2.2")
def calculate_average_temperature(temp_data_list):
    # Return 0.0 if the list is empty
    if len(temp_data_list) == 0:
        return 0.0

    total_temperature = 0

    # Calculate the total temperature
    for reading in temp_data_list:
        total_temperature += reading["temperature_celsius"]

    # Calculate the average
    average = total_temperature / len(temp_data_list)

    return average


# Example usage
average_temp = calculate_average_temperature(temperature_readings)

print("Average Temperature:", round(average_temp, 2), "°C")

# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
print("\n")
print("task-2.3")
def generate_report_line(reading_dict):
    return (f"[{reading_dict['timestamp']}] "
            f"Device {reading_dict['device_id']} at "
            f"{reading_dict['location']}: "
            f"{reading_dict['temperature_celsius']}°C")


# Example usage
print(generate_report_line(temperature_readings[0]))

# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
print("\n")
print("task-3.1")

print("Task 3: Core Library Usage ")

# Create a directory named 'sensor_reports' if it doesn't exist
reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
print("\n")
print("task-3.2")
import datetime
if len(raw_sensor_data) > 1:
    # Get the first and last timestamps
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert strings to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate the duration
    duration = last_dt - first_dt

    # Extract days, hours, and minutes
    days = duration.days
    remaining_seconds = duration.seconds
    hours = remaining_seconds // 3600
    minutes = (remaining_seconds % 3600) // 60

    print(f"Duration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

    # 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
print("\n")
print("task-3.3")
import random

# Generate a list of 5 random integers between 100 and 200 (inclusive)
random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("Random Values:", random_values)

# --- Task 4: File Handling in Python ---
# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.
# Your code for Task 4.1 here:

print("\ntask 4.1")
# Create the file path
report_filename = os.path.join(reports_dir, "temperature_report.txt")
try:
    # Open the file in write mode
    with open(report_filename, "w") as file:
        # Write each temperature reading to the file
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            file.write(line + "\n")

    print(f"Temperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

 # 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
# named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
# 4.2 Read the content of 'sensor_reports/temperature_report.txt'
#     back into a list of strings named 'read_report_lines'.
#     Print the first 3 lines.
print("\ntask-4.2")
read_report_lines = []

try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()

    print("First 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except FileNotFoundError:
    print(f"\nError: '{report_filename}' not found.")

except IOError as e:
    print(f"\nError reading the file: {e}")


print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-27 05:37:28', 'DEV001', 'Light_Sensor', 'Lab1', 549.71)
# ('2026-07-27 05:37:29', 'DEV002', 'Light_Sensor', 'OfficeA', 775.82)
# ('2026-07-27 05:37:30', 'DEV003', 'Light_Sensor', 'Warehouse', 727.62)
# ('2026-07-27 05:37:31', 'DEV004', 'Temperature_Sensor', 'Lab2', 20.81)
# ('2026-07-27 05:37:32', 'DEV005', 'Temperature_Sensor', 'OfficeA', 29.11)
#
#
# task-2
# {'timestamp': '2026-07-27 05:37:31', 'device_id': 'DEV004', 'location': 'Lab2', 'temperature_celsius': 20.81}
# {'timestamp': '2026-07-27 05:37:32', 'device_id': 'DEV005', 'location': 'OfficeA', 'temperature_celsius': 29.11}
# {'timestamp': '2026-07-27 05:37:36', 'device_id': 'DEV009', 'location': 'OfficeA', 'temperature_celsius': 29.87}
# {'timestamp': '2026-07-27 05:37:52', 'device_id': 'DEV025', 'location': 'Lab1', 'temperature_celsius': 18.81}
# {'timestamp': '2026-07-27 05:37:53', 'device_id': 'DEV026', 'location': 'Warehouse', 'temperature_celsius': 24.97}
# Total Temperature Readings: 22
#
#
# task-3
# {'Lab2', 'OfficeB', 'OfficeA', 'Lab1', 'Warehouse'}
# Number of unique locations: 5
#
#
# task-4
# Temperature_Sensor: Min = 18.81, Max = 29.87
# Humidity_Sensor: Min = 30.71, Max = 71.35
# Pressure_Sensor: Min = 981.55, Max = 1028.37
# Light_Sensor: Min = 191.54, Max = 983.43
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
#
# task-1.5.1
# Readings from 10th to 20th:
# ('2026-07-27 05:37:37', 'DEV010', 'Humidity_Sensor', 'OfficeA', 62.91)
# ('2026-07-27 05:37:38', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1003.85)
# ('2026-07-27 05:37:39', 'DEV012', 'Humidity_Sensor', 'Warehouse', 70.42)
# ('2026-07-27 05:37:40', 'DEV013', 'Light_Sensor', 'Lab1', 737.71)
# ('2026-07-27 05:37:41', 'DEV014', 'Humidity_Sensor', 'OfficeB', 45.29)
# ('2026-07-27 05:37:42', 'DEV015', 'Light_Sensor', 'Lab1', 733.69)
# ('2026-07-27 05:37:43', 'DEV016', 'Pressure_Sensor', 'Warehouse', 1027.39)
# ('2026-07-27 05:37:44', 'DEV017', 'Humidity_Sensor', 'Lab2', 71.35)
# ('2026-07-27 05:37:45', 'DEV018', 'Light_Sensor', 'OfficeA', 665.93)
# ('2026-07-27 05:37:46', 'DEV019', 'Pressure_Sensor', 'Lab2', 1014.34)
# ('2026-07-27 05:37:47', 'DEV020', 'Humidity_Sensor', 'OfficeB', 48.68)
#
# Every 5th reading:
# ('2026-07-27 05:37:28', 'DEV001', 'Light_Sensor', 'Lab1', 549.71)
# ('2026-07-27 05:37:33', 'DEV006', 'Pressure_Sensor', 'Warehouse', 984.84)
# ('2026-07-27 05:37:38', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1003.85)
# ('2026-07-27 05:37:43', 'DEV016', 'Pressure_Sensor', 'Warehouse', 1027.39)
# ('2026-07-27 05:37:48', 'DEV021', 'Humidity_Sensor', 'OfficeB', 71.06)
# ('2026-07-27 05:37:53', 'DEV026', 'Temperature_Sensor', 'Warehouse', 24.97)
# ('2026-07-27 05:37:58', 'DEV031', 'Pressure_Sensor', 'Lab2', 1013.07)
# ('2026-07-27 05:38:03', 'DEV036', 'Humidity_Sensor', 'OfficeA', 49.46)
# ('2026-07-27 05:38:08', 'DEV041', 'Humidity_Sensor', 'OfficeB', 58.45)
# ('2026-07-27 05:38:13', 'DEV046', 'Temperature_Sensor', 'Warehouse', 24.6)
# ('2026-07-27 05:38:18', 'DEV051', 'Light_Sensor', 'Warehouse', 714.09)
# ('2026-07-27 05:38:23', 'DEV056', 'Temperature_Sensor', 'Lab2', 29.78)
# ('2026-07-27 05:38:28', 'DEV061', 'Humidity_Sensor', 'OfficeA', 42.07)
# ('2026-07-27 05:38:33', 'DEV066', 'Temperature_Sensor', 'Lab2', 28.03)
# ('2026-07-27 05:38:38', 'DEV071', 'Temperature_Sensor', 'Warehouse', 18.96)
# ('2026-07-27 05:38:43', 'DEV076', 'Pressure_Sensor', 'Lab2', 986.97)
# ('2026-07-27 05:38:48', 'DEV081', 'Temperature_Sensor', 'OfficeA', 21.09)
# ('2026-07-27 05:38:53', 'DEV086', 'Light_Sensor', 'Lab1', 556.24)
# ('2026-07-27 05:38:58', 'DEV091', 'Pressure_Sensor', 'Lab1', 995.38)
# ('2026-07-27 05:39:03', 'DEV096', 'Light_Sensor', 'OfficeA', 644.44)
#
#
# task-1.5.2
# Substring 1: Programming
# Substring 2: nohtyP
#
#
# task-1.5.3
# 5th Reading Device Type: Temperature_Sensor
# Device Type Suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
#
#
# task-2.1
# Readings from Lab1:
# ('2026-07-27 05:37:28', 'DEV001', 'Light_Sensor', 'Lab1', 549.71)
# ('2026-07-27 05:37:40', 'DEV013', 'Light_Sensor', 'Lab1', 737.71)
# ('2026-07-27 05:37:42', 'DEV015', 'Light_Sensor', 'Lab1', 733.69)
# ('2026-07-27 05:37:52', 'DEV025', 'Temperature_Sensor', 'Lab1', 18.81)
# ('2026-07-27 05:37:54', 'DEV027', 'Pressure_Sensor', 'Lab1', 1019.74)
# Total Lab1 readings: 22
#
#
# task-2.2
# Average Temperature: 24.85 °C
#
#
# task-2.3
# [2026-07-27 05:37:31] Device DEV004 at Lab2: 20.81°C
#
# --- Task 3: Core Library Usage ---
#
#
# task-3.1
# Task 3: Core Library Usage
# Directory 'sensor_reports' already exists.
#
#
# task-3.2
# Duration of data collection: 0 days, 0 hours, 1 minutes.
#
#
# task-3.3
# Random Values: [180, 113, 168, 105, 180]
#
# task 4.1
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# task-4.2
# First 3 lines of the report:
# [2026-07-27 05:37:31] Device DEV004 at Lab2: 20.81°C
# [2026-07-27 05:37:32] Device DEV005 at OfficeA: 29.11°C
# [2026-07-27 05:37:36] Device DEV009 at OfficeA: 29.87°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
